# %% [markdown]
# # 需要安装的包
#
# ```
# pip install ipython-sql
# pip install sqlalchemy
# ```
#
# 对于 mysql，还需要安装
#
# ```
# pip install PyMySQL
# pip install mysqlclient
# ```
#
# 对于postgressql,还需要安装
#
# ```
# pip install psycopg2
# ```

# %%
# 加载包
# %load_ext sql

# %%
# 链接数据库
# %sql mysql+mysqldb://root:root@localhost/sakila

# %sql postgresql://postgres:password123@localhost/dvdrental

# %%
res= %sql select * from actor;
res2=res.DataFrame()
# Out:
#  * mysql+mysqldb://root:***@localhost/sakila
# 200 rows affected.

# %%
res2.head()
# Out:
#    actor_id first_name     last_name         last_update
# 0         1   PENELOPE       GUINESS 2006-02-15 04:34:33
# 1         2       NICK      WAHLBERG 2006-02-15 04:34:33
# 2         3         ED         CHASE 2006-02-15 04:34:33
# 3         4   JENNIFER         DAVIS 2006-02-15 04:34:33
# 4         5     JOHNNY  LOLLOBRIGIDA 2006-02-15 04:34:33

# %%
# 查询结果赋值及转换为 data frame

res=%sql select * from film limit 5;
res.DataFrame()
res
# Out:
#  * mysql+mysqldb://root:***@localhost/sakila
# 5 rows affected.
# [(1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (2, 'ACE GOLDFINGER', 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 48, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (4, 'AFFAIR PREJUDICE', 'A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank', 2006, 1, None, 5, Decimal('2.99'), 117, Decimal('26.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (5, 'AFRICAN EGG', 'A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico', 2006, 1, None, 6, Decimal('2.99'), 130, Decimal('22.99'), 'G', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))]

# %%
# 变量替换

length_var=90
# %sql select * from film where length< :length_var;
# Out:
#  * mysql+mysqldb://root:***@localhost/sakila
# 320 rows affected.
# [(1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (2, 'ACE GOLDFINGER', 'A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 48, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (7, 'AIRPLANE SIERRA', 'A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat', 2006, 1, None, 6, Decimal('4.99'), 62, Decimal('28.99'), 'PG-13', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (8, 'AIRPORT POLLOCK', 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India', 2006, 1, None, 6, Decimal('4.99'), 54, Decimal('15.99'), 'R', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (10, 'ALADDIN CALENDAR', 'A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China', 2006, 1, None, 6, Decimal('4.99'), 63, Decimal('24.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (15, 'ALIEN CENTER', 'A Brilliant Drama of a Cat And a Mad Scientist who must Battle a Feminist in A MySQL Convention', 2006, 1, None, 5, Decimal('2.99'), 46, Decimal('10.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (17, 'ALONE TRIP', 'A Fast-Paced Character Study of a Composer And a Dog who must Outgun a Boat in An Abandoned Fun House', 2006, 1, None, 3, Decimal('0.99'), 82, Decimal('14.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (18, 'ALTER VICTORY', 'A Thoughtful Drama of a Composer And a Feminist who must Meet a Secret Agent in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 57, Decimal('27.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (20, 'AMELIE HELLFIGHTERS', 'A Boring Drama of a Woman And a Squirrel who must Conquer a Student in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 79, Decimal('23.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (22, 'AMISTAD MIDSUMMER', 'A Emotional Character Study of a Dentist And a Crocodile who must Meet a Sumo Wrestler in California', 2006, 1, None, 6, Decimal('2.99'), 85, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (25, 'ANGELS LIFE', 'A Thoughtful Display of a Woman And a Astronaut who must Battle a Robot in Berlin', 2006, 1, None, 3, Decimal('2.99'), 74, Decimal('15.99'), 'G', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (26, 'ANNIE IDENTITY', 'A Amazing Panorama of a Pastry Chef And a Boat who must Escape a Woman in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 86, Decimal('15.99'), 'G', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (30, 'ANYTHING SAVANNAH', 'A Epic Story of a Pastry Chef And a Woman who must Chase a Feminist in An Abandoned Fun House', 2006, 1, None, 4, Decimal('2.99'), 82, Decimal('27.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (34, 'ARABIA DOGMA', 'A Touching Epistle of a Madman And a Mad Cow who must Defeat a Student in Nigeria', 2006, 1, None, 6, Decimal('0.99'), 62, Decimal('29.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (38, 'ARK RIDGEMONT', 'A Beautiful Yarn of a Pioneer And a Monkey who must Pursue a Explorer in The Sahara Desert', 2006, 1, None, 6, Decimal('0.99'), 68, Decimal('25.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (45, 'ATTRACTION NEWTON', 'A Astounding Panorama of a Composer And a Frisbee who must Reach a Husband in Ancient Japan', 2006, 1, None, 5, Decimal('4.99'), 83, Decimal('14.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (51, 'BALLOON HOMEWARD', 'A Insightful Panorama of a Forensic Psychologist And a Mad Cow who must Build a Mad Scientist in The First Manned Space Station', 2006, 1, None, 5, Decimal('2.99'), 75, Decimal('10.99'), 'NC-17', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (53, 'BANG KWAI', 'A Epic Drama of a Madman And a Cat who must Face a A Shark in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('2.99'), 87, Decimal('25.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (55, 'BARBARELLA STREETCAR', 'A Awe-Inspiring Story of a Feminist And a Cat who must Conquer a Dog in A Monastery', 2006, 1, None, 6, Decimal('2.99'), 65, Decimal('27.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (60, 'BEAST HUNCHBACK', 'A Awe-Inspiring Epistle of a Student And a Squirrel who must Defeat a Boy in Ancient China', 2006, 1, None, 3, Decimal('4.99'), 89, Decimal('22.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (63, 'BEDAZZLED MARRIED', 'A Astounding Character Study of a Madman And a Robot who must Meet a Mad Scientist in An Abandoned Fun House', 2006, 1, None, 6, Decimal('0.99'), 73, Decimal('21.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (66, 'BENEATH RUSH', 'A Astounding Panorama of a Man And a Monkey who must Discover a Man in The First Manned Space Station', 2006, 1, None, 6, Decimal('0.99'), 53, Decimal('27.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (67, 'BERETS AGENT', 'A Taut Saga of a Crocodile And a Boy who must Overcome a Technical Writer in Ancient China', 2006, 1, None, 5, Decimal('2.99'), 77, Decimal('24.99'), 'PG-13', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (69, 'BEVERLY OUTLAW', 'A Fanciful Documentary of a Womanizer And a Boat who must Defeat a Madman in The First Manned Space Station', 2006, 1, None, 3, Decimal('2.99'), 85, Decimal('21.99'), 'R', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (77, 'BIRDS PERDITION', 'A Boring Story of a Womanizer And a Pioneer who must Face a Dog in California', 2006, 1, None, 5, Decimal('4.99'), 61, Decimal('15.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (78, 'BLACKOUT PRIVATE', 'A Intrepid Yarn of a Pastry Chef And a Mad Scientist who must Challenge a Secret Agent in Ancient Japan', 2006, 1, None, 7, Decimal('2.99'), 85, Decimal('12.99'), 'PG', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (82, 'BLOOD ARGONAUTS', 'A Boring Drama of a Explorer And a Man who must Kill a Lumberjack in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 71, Decimal('13.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (83, 'BLUES INSTINCT', 'A Insightful Documentary of a Boat And a Composer who must Meet a Forensic Psychologist in An Abandoned Fun House', 2006, 1, None, 5, Decimal('2.99'), 50, Decimal('18.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (85, 'BONNIE HOLOCAUST', 'A Fast-Paced Story of a Crocodile And a Robot who must Find a Moose in Ancient Japan', 2006, 1, None, 4, Decimal('0.99'), 63, Decimal('29.99'), 'G', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (87, 'BOONDOCK BALLROOM', 'A Fateful Panorama of a Crocodile And a Boy who must Defeat a Monkey in The Gulf of Mexico', 2006, 1, None, 7, Decimal('0.99'), 76, Decimal('14.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (89, 'BORROWERS BEDAZZLED', 'A Brilliant Epistle of a Teacher And a Sumo Wrestler who must Defeat a Man in An Abandoned Fun House', 2006, 1, None, 7, Decimal('0.99'), 63, Decimal('22.99'), 'G', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (90, 'BOULEVARD MOB', 'A Fateful Epistle of a Moose And a Monkey who must Confront a Lumberjack in Ancient China', 2006, 1, None, 3, Decimal('0.99'), 63, Decimal('11.99'), 'R', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (92, 'BOWFINGER GABLES', 'A Fast-Paced Yarn of a Waitress And a Composer who must Outgun a Dentist in California', 2006, 1, None, 7, Decimal('4.99'), 72, Decimal('19.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (97, 'BRIDE INTRIGUE', 'A Epic Tale of a Robot And a Monkey who must Vanquish a Man in New Orleans', 2006, 1, None, 7, Decimal('0.99'), 56, Decimal('24.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (98, 'BRIGHT ENCOUNTERS', 'A Fateful Yarn of a Lumberjack And a Feminist who must Conquer a Student in A Jet Boat', 2006, 1, None, 4, Decimal('4.99'), 73, Decimal('12.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (101, 'BROTHERHOOD BLANKET', 'A Fateful Character Study of a Butler And a Technical Writer who must Sink a Astronaut in Ancient Japan', 2006, 1, None, 3, Decimal('0.99'), 73, Decimal('26.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (102, 'BUBBLE GROSSE', 'A Awe-Inspiring Panorama of a Crocodile And a Moose who must Confront a Girl in A Baloon', 2006, 1, None, 4, Decimal('4.99'), 60, Decimal('20.99'), 'R', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (106, 'BULWORTH COMMANDMENTS', 'A Amazing Display of a Mad Cow And a Pioneer who must Redeem a Sumo Wrestler in The Outback', 2006, 1, None, 4, Decimal('2.99'), 61, Decimal('14.99'), 'G', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (107, 'BUNCH MINDS', 'A Emotional Story of a Feminist And a Feminist who must Escape a Pastry Chef in A MySQL Convention', 2006, 1, None, 4, Decimal('2.99'), 63, Decimal('13.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (108, 'BUTCH PANTHER', 'A Lacklusture Yarn of a Feminist And a Database Administrator who must Face a Hunter in New Orleans', 2006, 1, None, 6, Decimal('0.99'), 67, Decimal('19.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (109, 'BUTTERFLY CHOCOLAT', 'A Fateful Story of a Girl And a Composer who must Conquer a Husband in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 89, Decimal('17.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (110, 'CABIN FLASH', 'A Stunning Epistle of a Boat And a Man who must Challenge a A Shark in A Baloon Factory', 2006, 1, None, 4, Decimal('0.99'), 53, Decimal('25.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (111, 'CADDYSHACK JEDI', 'A Awe-Inspiring Epistle of a Woman And a Madman who must Fight a Robot in Soviet Georgia', 2006, 1, None, 3, Decimal('0.99'), 52, Decimal('17.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (113, 'CALIFORNIA BIRDS', 'A Thrilling Yarn of a Database Administrator And a Robot who must Battle a Database Administrator in Ancient India', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('19.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (114, 'CAMELOT VACATION', 'A Touching Character Study of a Woman And a Waitress who must Battle a Pastry Chef in A MySQL Convention', 2006, 1, None, 3, Decimal('0.99'), 61, Decimal('26.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (116, 'CANDIDATE PERDITION', 'A Brilliant Epistle of a Composer And a Database Administrator who must Vanquish a Mad Scientist in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 70, Decimal('10.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (118, 'CANYON STOCK', 'A Thoughtful Reflection of a Waitress And a Feminist who must Escape a Squirrel in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 85, Decimal('26.99'), 'R', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (123, 'CASABLANCA SUPER', 'A Amazing Panorama of a Crocodile And a Forensic Psychologist who must Pursue a Secret Agent in The First Manned Space Station', 2006, 1, None, 6, Decimal('4.99'), 85, Decimal('22.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (125, 'CASSIDY WYOMING', 'A Intrepid Drama of a Frisbee And a Hunter who must Kill a Secret Agent in New Orleans', 2006, 1, None, 5, Decimal('2.99'), 61, Decimal('19.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (134, 'CHAMPION FLATLINERS', 'A Amazing Story of a Mad Cow And a Dog who must Kill a Husband in A Monastery', 2006, 1, None, 4, Decimal('4.99'), 51, Decimal('21.99'), 'PG', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (135, 'CHANCE RESURRECTION', 'A Astounding Story of a Forensic Psychologist And a Forensic Psychologist who must Overcome a Moose in Ancient China', 2006, 1, None, 3, Decimal('2.99'), 70, Decimal('22.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (137, 'CHARADE DUFFEL', 'A Action-Packed Display of a Man And a Waitress who must Build a Dog in A MySQL Convention', 2006, 1, None, 3, Decimal('2.99'), 66, Decimal('21.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (138, 'CHARIOTS CONSPIRACY', 'A Unbelieveable Epistle of a Robot And a Husband who must Chase a Robot in The First Manned Space Station', 2006, 1, None, 5, Decimal('2.99'), 71, Decimal('29.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (140, 'CHEAPER CLYDE', 'A Emotional Character Study of a Pioneer And a Girl who must Discover a Dog in Ancient Japan', 2006, 1, None, 6, Decimal('0.99'), 87, Decimal('23.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (144, 'CHINATOWN GLADIATOR', 'A Brilliant Panorama of a Technical Writer And a Lumberjack who must Escape a Butler in Ancient India', 2006, 1, None, 7, Decimal('4.99'), 61, Decimal('24.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (154, 'CLASH FREDDY', 'A Amazing Yarn of a Composer And a Squirrel who must Escape a Astronaut in Australia', 2006, 1, None, 6, Decimal('2.99'), 81, Decimal('12.99'), 'G', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (159, 'CLOSER BANG', 'A Unbelieveable Panorama of a Frisbee And a Hunter who must Vanquish a Monkey in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 58, Decimal('12.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (160, 'CLUB GRAFFITI', 'A Epic Tale of a Pioneer And a Hunter who must Escape a Girl in A U-Boat', 2006, 1, None, 4, Decimal('0.99'), 65, Decimal('12.99'), 'PG-13', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (161, 'CLUE GRAIL', 'A Taut Tale of a Butler And a Mad Scientist who must Build a Crocodile in Ancient China', 2006, 1, None, 6, Decimal('4.99'), 70, Decimal('27.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (164, 'COAST RAINBOW', 'A Astounding Documentary of a Mad Cow And a Pioneer who must Challenge a Butler in The Sahara Desert', 2006, 1, None, 4, Decimal('0.99'), 55, Decimal('20.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (165, 'COLDBLOODED DARLING', 'A Brilliant Panorama of a Dentist And a Moose who must Find a Student in The Gulf of Mexico', 2006, 1, None, 7, Decimal('4.99'), 70, Decimal('27.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (168, 'COMANCHEROS ENEMY', 'A Boring Saga of a Lumberjack And a Monkey who must Find a Monkey in The Gulf of Mexico', 2006, 1, None, 5, Decimal('0.99'), 67, Decimal('23.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (169, 'COMFORTS RUSH', 'A Unbelieveable Panorama of a Pioneer And a Husband who must Meet a Mad Cow in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('2.99'), 76, Decimal('19.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (171, 'COMMANDMENTS EXPRESS', 'A Fanciful Saga of a Student And a Mad Scientist who must Battle a Hunter in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('4.99'), 59, Decimal('13.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (173, 'CONFESSIONS MAGUIRE', 'A Insightful Story of a Car And a Boy who must Battle a Technical Writer in A Baloon', 2006, 1, None, 7, Decimal('4.99'), 65, Decimal('25.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (176, 'CONGENIALITY QUEST', 'A Touching Documentary of a Cat And a Pastry Chef who must Find a Lumberjack in A Baloon', 2006, 1, None, 6, Decimal('0.99'), 87, Decimal('21.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (186, 'CRAFT OUTFIELD', 'A Lacklusture Display of a Explorer And a Hunter who must Succumb a Database Administrator in A Baloon Factory', 2006, 1, None, 6, Decimal('0.99'), 64, Decimal('17.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (187, 'CRANES RESERVOIR', 'A Fanciful Documentary of a Teacher And a Dog who must Outgun a Forensic Psychologist in A Baloon Factory', 2006, 1, None, 5, Decimal('2.99'), 57, Decimal('12.99'), 'NC-17', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (192, 'CROSSING DIVORCE', 'A Beautiful Documentary of a Dog And a Robot who must Redeem a Womanizer in Berlin', 2006, 1, None, 4, Decimal('4.99'), 50, Decimal('19.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (196, 'CRUELTY UNFORGIVEN', 'A Brilliant Tale of a Car And a Moose who must Battle a Dentist in Nigeria', 2006, 1, None, 7, Decimal('0.99'), 69, Decimal('29.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (199, 'CUPBOARD SINNERS', 'A Emotional Reflection of a Frisbee And a Boat who must Reach a Pastry Chef in An Abandoned Amusement Park', 2006, 1, None, 4, Decimal('2.99'), 56, Decimal('29.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (203, 'DAISY MENAGERIE', 'A Fast-Paced Saga of a Pastry Chef And a Monkey who must Sink a Composer in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 84, Decimal('9.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (205, 'DANCES NONE', 'A Insightful Reflection of a A Shark And a Dog who must Kill a Butler in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 58, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (208, 'DARES PLUTO', 'A Fateful Story of a Robot And a Dentist who must Defeat a Astronaut in New Orleans', 2006, 1, None, 7, Decimal('2.99'), 89, Decimal('16.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (214, 'DAUGHTER MADIGAN', 'A Beautiful Tale of a Hunter And a Mad Scientist who must Confront a Squirrel in The First Manned Space Station', 2006, 1, None, 3, Decimal('4.99'), 59, Decimal('13.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (215, 'DAWN POND', 'A Thoughtful Documentary of a Dentist And a Forensic Psychologist who must Defeat a Waitress in Berlin', 2006, 1, None, 4, Decimal('4.99'), 57, Decimal('27.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (219, 'DEEP CRUSADE', 'A Amazing Tale of a Crocodile And a Squirrel who must Discover a Composer in Australia', 2006, 1, None, 6, Decimal('4.99'), 51, Decimal('20.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (222, 'DESERT POSEIDON', 'A Brilliant Documentary of a Butler And a Frisbee who must Build a Astronaut in New Orleans', 2006, 1, None, 4, Decimal('4.99'), 64, Decimal('27.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (223, 'DESIRE ALIEN', 'A Fast-Paced Tale of a Dog And a Forensic Psychologist who must Meet a Astronaut in The First Manned Space Station', 2006, 1, None, 7, Decimal('2.99'), 76, Decimal('24.99'), 'NC-17', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (224, 'DESPERATE TRAINSPOTTING', 'A Epic Yarn of a Forensic Psychologist And a Teacher who must Face a Lumberjack in California', 2006, 1, None, 7, Decimal('4.99'), 81, Decimal('29.99'), 'G', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (225, 'DESTINATION JERK', 'A Beautiful Yarn of a Teacher And a Cat who must Build a Car in A U-Boat', 2006, 1, None, 3, Decimal('0.99'), 76, Decimal('19.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (226, 'DESTINY SATURDAY', 'A Touching Drama of a Crocodile And a Crocodile who must Conquer a Explorer in Soviet Georgia', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('20.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (227, 'DETAILS PACKER', 'A Epic Saga of a Waitress And a Composer who must Face a Boat in A U-Boat', 2006, 1, None, 4, Decimal('4.99'), 88, Decimal('17.99'), 'R', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (229, 'DEVIL DESIRE', 'A Beautiful Reflection of a Monkey And a Dentist who must Face a Database Administrator in Ancient Japan', 2006, 1, None, 6, Decimal('4.99'), 87, Decimal('12.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (231, 'DINOSAUR SECRETARY', 'A Action-Packed Drama of a Feminist And a Girl who must Reach a Robot in The Canadian Rockies', 2006, 1, None, 7, Decimal('2.99'), 63, Decimal('27.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (235, 'DIVIDE MONSTER', 'A Intrepid Saga of a Man And a Forensic Psychologist who must Reach a Squirrel in A Monastery', 2006, 1, None, 6, Decimal('2.99'), 68, Decimal('13.99'), 'PG-13', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (237, 'DIVORCE SHINING', 'A Unbelieveable Saga of a Crocodile And a Student who must Discover a Cat in Ancient India', 2006, 1, None, 3, Decimal('2.99'), 47, Decimal('21.99'), 'G', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (238, 'DOCTOR GRAIL', 'A Insightful Drama of a Womanizer And a Waitress who must Reach a Forensic Psychologist in The Outback', 2006, 1, None, 4, Decimal('2.99'), 57, Decimal('29.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (242, 'DOOM DANCING', 'A Astounding Panorama of a Car And a Mad Scientist who must Battle a Lumberjack in A MySQL Convention', 2006, 1, None, 4, Decimal('0.99'), 68, Decimal('13.99'), 'R', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (243, 'DOORS PRESIDENT', 'A Awe-Inspiring Display of a Squirrel And a Woman who must Overcome a Boy in The Gulf of Mexico', 2006, 1, None, 3, Decimal('4.99'), 49, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (247, 'DOWNHILL ENOUGH', 'A Emotional Tale of a Pastry Chef And a Forensic Psychologist who must Succumb a Monkey in The Sahara Desert', 2006, 1, None, 3, Decimal('0.99'), 47, Decimal('19.99'), 'G', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (253, 'DRIFTER COMMANDMENTS', 'A Epic Reflection of a Womanizer And a Squirrel who must Discover a Husband in A Jet Boat', 2006, 1, None, 5, Decimal('4.99'), 61, Decimal('18.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (270, 'EARTH VISION', 'A Stunning Drama of a Butler And a Madman who must Outrace a Womanizer in Ancient India', 2006, 1, None, 7, Decimal('0.99'), 85, Decimal('29.99'), 'NC-17', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (274, 'EGG IGBY', 'A Beautiful Documentary of a Boat And a Sumo Wrestler who must Succumb a Database Administrator in The First Manned Space Station', 2006, 1, None, 4, Decimal('2.99'), 67, Decimal('20.99'), 'PG', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (275, 'EGYPT TENENBAUMS', 'A Intrepid Story of a Madman And a Secret Agent who must Outrace a Astronaut in An Abandoned Amusement Park', 2006, 1, None, 3, Decimal('0.99'), 85, Decimal('11.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (283, 'ENDING CROWDS', 'A Unbelieveable Display of a Dentist And a Madman who must Vanquish a Squirrel in Berlin', 2006, 1, None, 6, Decimal('0.99'), 85, Decimal('10.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (284, 'ENEMY ODDS', 'A Fanciful Panorama of a Mad Scientist And a Woman who must Pursue a Astronaut in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 77, Decimal('23.99'), 'NC-17', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (285, 'ENGLISH BULWORTH', 'A Intrepid Epistle of a Pastry Chef And a Pastry Chef who must Pursue a Crocodile in Ancient China', 2006, 1, None, 3, Decimal('0.99'), 51, Decimal('18.99'), 'PG-13', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (289, 'EVE RESURRECTION', 'A Awe-Inspiring Yarn of a Pastry Chef And a Database Administrator who must Challenge a Teacher in A Baloon', 2006, 1, None, 5, Decimal('4.99'), 66, Decimal('25.99'), 'G', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (292, 'EXCITEMENT EVE', 'A Brilliant Documentary of a Monkey And a Car who must Conquer a Crocodile in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 51, Decimal('20.99'), 'G', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (303, 'FANTASY TROOPERS', 'A Touching Saga of a Teacher And a Monkey who must Overcome a Secret Agent in A MySQL Convention', 2006, 1, None, 6, Decimal('0.99'), 58, Decimal('27.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (307, 'FELLOWSHIP AUTUMN', 'A Lacklusture Reflection of a Dentist And a Hunter who must Meet a Teacher in A Baloon', 2006, 1, None, 6, Decimal('4.99'), 77, Decimal('9.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (311, 'FICTION CHRISTMAS', 'A Emotional Yarn of a A Shark And a Student who must Battle a Robot in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('0.99'), 72, Decimal('14.99'), 'PG', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (312, 'FIDDLER LOST', 'A Boring Tale of a Squirrel And a Dog who must Challenge a Madman in The Gulf of Mexico', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('20.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (320, 'FLAMINGOS CONNECTICUT', 'A Fast-Paced Reflection of a Composer And a Composer who must Meet a Cat in The Sahara Desert', 2006, 1, None, 4, Decimal('4.99'), 80, Decimal('28.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (326, 'FLYING HOOK', 'A Thrilling Display of a Mad Cow And a Dog who must Challenge a Frisbee in Nigeria', 2006, 1, None, 6, Decimal('2.99'), 69, Decimal('18.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (329, 'FORREST SONS', 'A Thrilling Documentary of a Forensic Psychologist And a Butler who must Defeat a Explorer in A Jet Boat', 2006, 1, None, 4, Decimal('2.99'), 63, Decimal('15.99'), 'R', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (334, 'FREDDY STORM', 'A Intrepid Saga of a Man And a Lumberjack who must Vanquish a Husband in The Outback', 2006, 1, None, 6, Decimal('4.99'), 65, Decimal('21.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (337, 'FRIDA SLIPPER', 'A Fateful Story of a Lumberjack And a Car who must Escape a Boat in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('2.99'), 73, Decimal('11.99'), 'R', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (338, 'FRISCO FORREST', 'A Beautiful Documentary of a Woman And a Pioneer who must Pursue a Mad Scientist in A Shark Tank', 2006, 1, None, 6, Decimal('4.99'), 51, Decimal('23.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (341, 'FROST HEAD', 'A Amazing Reflection of a Lumberjack And a Cat who must Discover a Husband in A MySQL Convention', 2006, 1, None, 5, Decimal('0.99'), 82, Decimal('13.99'), 'PG', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (342, 'FUGITIVE MAGUIRE', 'A Taut Epistle of a Feminist And a Sumo Wrestler who must Battle a Crocodile in Australia', 2006, 1, None, 7, Decimal('4.99'), 83, Decimal('28.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (348, 'GANDHI KWAI', 'A Thoughtful Display of a Mad Scientist And a Secret Agent who must Chase a Boat in Berlin', 2006, 1, None, 7, Decimal('0.99'), 86, Decimal('9.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (350, 'GARDEN ISLAND', 'A Unbelieveable Character Study of a Womanizer And a Madman who must Reach a Man in The Outback', 2006, 1, None, 3, Decimal('4.99'), 80, Decimal('21.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (354, 'GHOST GROUNDHOG', 'A Brilliant Panorama of a Madman And a Composer who must Succumb a Car in Ancient India', 2006, 1, None, 6, Decimal('4.99'), 85, Decimal('18.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (361, 'GLEAMING JAWBREAKER', 'A Amazing Display of a Composer And a Forensic Psychologist who must Discover a Car in The Canadian Rockies', 2006, 1, None, 5, Decimal('2.99'), 89, Decimal('25.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (363, 'GO PURPLE', 'A Fast-Paced Display of a Car And a Database Administrator who must Battle a Woman in A Baloon', 2006, 1, None, 3, Decimal('0.99'), 54, Decimal('12.99'), 'R', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (364, 'GODFATHER DIARY', 'A Stunning Saga of a Lumberjack And a Squirrel who must Chase a Car in The Outback', 2006, 1, None, 3, Decimal('2.99'), 73, Decimal('14.99'), 'NC-17', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (368, 'GONE TROUBLE', 'A Insightful Character Study of a Mad Cow And a Forensic Psychologist who must Conquer a A Shark in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('2.99'), 84, Decimal('20.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (369, 'GOODFELLAS SALUTE', 'A Unbelieveable Tale of a Dog And a Explorer who must Sink a Mad Cow in A Baloon Factory', 2006, 1, None, 4, Decimal('4.99'), 56, Decimal('22.99'), 'PG', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (375, 'GRAIL FRANKENSTEIN', 'A Unbelieveable Saga of a Teacher And a Monkey who must Fight a Girl in An Abandoned Mine Shaft', 2006, 1, None, 4, Decimal('2.99'), 85, Decimal('17.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (384, 'GROSSE WONDERFUL', 'A Epic Drama of a Cat And a Explorer who must Redeem a Moose in Australia', 2006, 1, None, 5, Decimal('4.99'), 49, Decimal('19.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (386, 'GUMP DATE', 'A Intrepid Yarn of a Explorer And a Student who must Kill a Husband in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('4.99'), 53, Decimal('12.99'), 'NC-17', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (388, 'GUNFIGHT MOON', 'A Epic Reflection of a Pastry Chef And a Explorer who must Reach a Dentist in The Sahara Desert', 2006, 1, None, 5, Decimal('0.99'), 70, Decimal('16.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (390, 'GUYS FALCON', 'A Boring Story of a Woman And a Feminist who must Redeem a Squirrel in A U-Boat', 2006, 1, None, 4, Decimal('4.99'), 84, Decimal('20.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (392, 'HALL CASSIDY', 'A Beautiful Panorama of a Pastry Chef And a A Shark who must Battle a Pioneer in Soviet Georgia', 2006, 1, None, 5, Decimal('4.99'), 51, Decimal('13.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (393, 'HALLOWEEN NUTS', 'A Amazing Panorama of a Forensic Psychologist And a Technical Writer who must Fight a Dentist in A U-Boat', 2006, 1, None, 6, Decimal('2.99'), 47, Decimal('19.99'), 'PG-13', 'Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (396, 'HANGING DEEP', 'A Action-Packed Yarn of a Boat And a Crocodile who must Build a Monkey in Berlin', 2006, 1, None, 5, Decimal('4.99'), 62, Decimal('18.99'), 'G', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (398, 'HANOVER GALAXY', 'A Stunning Reflection of a Girl And a Secret Agent who must Succumb a Boy in A MySQL Convention', 2006, 1, None, 5, Decimal('4.99'), 47, Decimal('21.99'), 'NC-17', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (400, 'HARDLY ROBBERS', 'A Emotional Character Study of a Hunter And a Car who must Kill a Woman in Berlin', 2006, 1, None, 7, Decimal('2.99'), 72, Decimal('15.99'), 'R', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (402, 'HARPER DYING', 'A Awe-Inspiring Reflection of a Woman And a Cat who must Confront a Feminist in The Sahara Desert', 2006, 1, None, 3, Decimal('0.99'), 52, Decimal('15.99'), 'G', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (405, 'HAUNTED ANTITRUST', 'A Amazing Saga of a Man And a Dentist who must Reach a Technical Writer in Ancient India', 2006, 1, None, 6, Decimal('4.99'), 76, Decimal('13.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (407, 'HAWK CHILL', 'A Action-Packed Drama of a Mad Scientist And a Composer who must Outgun a Car in Australia', 2006, 1, None, 5, Decimal('0.99'), 47, Decimal('12.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (408, 'HEAD STRANGER', 'A Thoughtful Saga of a Hunter And a Crocodile who must Confront a Dog in The Gulf of Mexico', 2006, 1, None, 4, Decimal('4.99'), 69, Decimal('28.99'), 'R', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (409, 'HEARTBREAKERS BRIGHT', 'A Awe-Inspiring Documentary of a A Shark And a Dentist who must Outrace a Pastry Chef in The Canadian Rockies', 2006, 1, None, 3, Decimal('4.99'), 59, Decimal('9.99'), 'G', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (410, 'HEAVEN FREEDOM', 'A Intrepid Story of a Butler And a Car who must Vanquish a Man in New Orleans', 2006, 1, None, 7, Decimal('2.99'), 48, Decimal('19.99'), 'PG', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (411, 'HEAVENLY GUN', 'A Beautiful Yarn of a Forensic Psychologist And a Frisbee who must Battle a Moose in A Jet Boat', 2006, 1, None, 5, Decimal('4.99'), 49, Decimal('13.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (414, 'HELLFIGHTERS SIERRA', 'A Taut Reflection of a A Shark And a Dentist who must Battle a Boat in Soviet Georgia', 2006, 1, None, 3, Decimal('2.99'), 75, Decimal('23.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (415, 'HIGH ENCINO', 'A Fateful Saga of a Waitress And a Hunter who must Outrace a Sumo Wrestler in Australia', 2006, 1, None, 3, Decimal('2.99'), 84, Decimal('23.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (421, 'HOLIDAY GAMES', 'A Insightful Reflection of a Waitress And a Madman who must Pursue a Boy in Ancient Japan', 2006, 1, None, 7, Decimal('4.99'), 78, Decimal('10.99'), 'PG-13', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (423, 'HOLLYWOOD ANONYMOUS', 'A Fast-Paced Epistle of a Boy And a Explorer who must Escape a Dog in A U-Boat', 2006, 1, None, 7, Decimal('0.99'), 69, Decimal('29.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (425, 'HOLY TADPOLE', 'A Action-Packed Display of a Feminist And a Pioneer who must Pursue a Dog in A Baloon Factory', 2006, 1, None, 6, Decimal('0.99'), 88, Decimal('20.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (429, 'HONEY TIES', 'A Taut Story of a Waitress And a Crocodile who must Outrace a Lumberjack in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 84, Decimal('29.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (430, 'HOOK CHARIOTS', 'A Insightful Story of a Boy And a Dog who must Redeem a Boy in Australia', 2006, 1, None, 7, Decimal('0.99'), 49, Decimal('23.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (438, 'HUMAN GRAFFITI', 'A Beautiful Reflection of a Womanizer And a Sumo Wrestler who must Chase a Database Administrator in The Gulf of Mexico', 2006, 1, None, 3, Decimal('2.99'), 68, Decimal('22.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (442, 'HUNTING MUSKETEERS', 'A Thrilling Reflection of a Pioneer And a Dentist who must Outrace a Womanizer in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('2.99'), 65, Decimal('24.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (443, 'HURRICANE AFFAIR', 'A Lacklusture Epistle of a Database Administrator And a Woman who must Meet a Hunter in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('2.99'), 49, Decimal('11.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (444, 'HUSTLER PARTY', 'A Emotional Reflection of a Sumo Wrestler And a Monkey who must Conquer a Robot in The Sahara Desert', 2006, 1, None, 3, Decimal('4.99'), 83, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (450, 'IDOLS SNATCHERS', 'A Insightful Drama of a Car And a Composer who must Fight a Man in A Monastery', 2006, 1, None, 5, Decimal('2.99'), 84, Decimal('29.99'), 'NC-17', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (459, 'INFORMER DOUBLE', 'A Action-Packed Display of a Woman And a Dentist who must Redeem a Forensic Psychologist in The Canadian Rockies', 2006, 1, None, 4, Decimal('4.99'), 74, Decimal('23.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (462, 'INSIDER ARIZONA', 'A Astounding Saga of a Mad Scientist And a Hunter who must Pursue a Robot in A Baloon Factory', 2006, 1, None, 5, Decimal('2.99'), 78, Decimal('17.99'), 'NC-17', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (465, 'INTERVIEW LIAISONS', 'A Action-Packed Reflection of a Student And a Butler who must Discover a Database Administrator in A Manhattan Penthouse', 2006, 1, None, 4, Decimal('4.99'), 59, Decimal('17.99'), 'R', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (466, 'INTOLERABLE INTENTIONS', 'A Awe-Inspiring Story of a Monkey And a Pastry Chef who must Succumb a Womanizer in A MySQL Convention', 2006, 1, None, 6, Decimal('4.99'), 63, Decimal('20.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (469, 'IRON MOON', 'A Fast-Paced Documentary of a Mad Cow And a Boy who must Pursue a Dentist in A Baloon', 2006, 1, None, 7, Decimal('4.99'), 46, Decimal('27.99'), 'PG', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (470, 'ISHTAR ROCKETEER', 'A Astounding Saga of a Dog And a Squirrel who must Conquer a Dog in An Abandoned Fun House', 2006, 1, None, 4, Decimal('4.99'), 79, Decimal('24.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (471, 'ISLAND EXORCIST', 'A Fanciful Panorama of a Technical Writer And a Boy who must Find a Dentist in An Abandoned Fun House', 2006, 1, None, 7, Decimal('2.99'), 84, Decimal('23.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (480, 'JEEPERS WEDDING', 'A Astounding Display of a Composer And a Dog who must Kill a Pastry Chef in Soviet Georgia', 2006, 1, None, 3, Decimal('2.99'), 84, Decimal('29.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (481, 'JEKYLL FROGMEN', 'A Fanciful Epistle of a Student And a Astronaut who must Kill a Waitress in A Shark Tank', 2006, 1, None, 4, Decimal('2.99'), 58, Decimal('22.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (485, 'JERSEY SASSY', 'A Lacklusture Documentary of a Madman And a Mad Cow who must Find a Feminist in Ancient Japan', 2006, 1, None, 6, Decimal('4.99'), 60, Decimal('16.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (486, 'JET NEIGHBORS', 'A Amazing Display of a Lumberjack And a Teacher who must Outrace a Woman in A U-Boat', 2006, 1, None, 7, Decimal('4.99'), 59, Decimal('14.99'), 'R', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (489, 'JUGGLER HARDLY', 'A Epic Story of a Mad Cow And a Astronaut who must Challenge a Car in California', 2006, 1, None, 4, Decimal('0.99'), 54, Decimal('14.99'), 'PG-13', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (491, 'JUMPING WRATH', 'A Touching Epistle of a Monkey And a Feminist who must Discover a Boat in Berlin', 2006, 1, None, 4, Decimal('0.99'), 74, Decimal('18.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (497, 'KILL BROTHERHOOD', 'A Touching Display of a Hunter And a Secret Agent who must Redeem a Husband in The Outback', 2006, 1, None, 4, Decimal('0.99'), 54, Decimal('15.99'), 'G', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (502, 'KNOCK WARLOCK', 'A Unbelieveable Story of a Teacher And a Boat who must Confront a Moose in A Baloon', 2006, 1, None, 4, Decimal('2.99'), 71, Decimal('21.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (504, 'KWAI HOMEWARD', 'A Amazing Drama of a Car And a Squirrel who must Pursue a Car in Soviet Georgia', 2006, 1, None, 5, Decimal('0.99'), 46, Decimal('25.99'), 'PG-13', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (505, 'LABYRINTH LEAGUE', 'A Awe-Inspiring Saga of a Composer And a Frisbee who must Succumb a Pioneer in The Sahara Desert', 2006, 1, None, 6, Decimal('2.99'), 46, Decimal('24.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (506, 'LADY STAGE', 'A Beautiful Character Study of a Woman And a Man who must Pursue a Explorer in A U-Boat', 2006, 1, None, 4, Decimal('4.99'), 67, Decimal('14.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (509, 'LANGUAGE COWBOY', 'A Epic Yarn of a Cat And a Madman who must Vanquish a Dentist in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('0.99'), 78, Decimal('26.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (514, 'LEBOWSKI SOLDIERS', 'A Beautiful Epistle of a Secret Agent And a Pioneer who must Chase a Astronaut in Ancient China', 2006, 1, None, 6, Decimal('2.99'), 69, Decimal('17.99'), 'PG-13', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (516, 'LEGEND JEDI', 'A Awe-Inspiring Epistle of a Pioneer And a Student who must Outgun a Crocodile in The Outback', 2006, 1, None, 7, Decimal('0.99'), 59, Decimal('18.99'), 'PG', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (524, 'LION UNCUT', 'A Intrepid Display of a Pastry Chef And a Cat who must Kill a A Shark in Ancient China', 2006, 1, None, 6, Decimal('0.99'), 50, Decimal('13.99'), 'PG', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (527, 'LOLA AGENT', 'A Astounding Tale of a Mad Scientist And a Husband who must Redeem a Database Administrator in Ancient Japan', 2006, 1, None, 4, Decimal('4.99'), 85, Decimal('24.99'), 'PG', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (529, 'LONELY ELEPHANT', 'A Intrepid Story of a Student And a Dog who must Challenge a Explorer in Soviet Georgia', 2006, 1, None, 3, Decimal('2.99'), 67, Decimal('12.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (532, 'LOSER HUSTLER', 'A Stunning Drama of a Robot And a Feminist who must Outgun a Butler in Nigeria', 2006, 1, None, 5, Decimal('4.99'), 80, Decimal('28.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (534, 'LOUISIANA HARRY', 'A Lacklusture Drama of a Girl And a Technical Writer who must Redeem a Monkey in A Shark Tank', 2006, 1, None, 5, Decimal('0.99'), 70, Decimal('18.99'), 'PG-13', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (536, 'LOVELY JINGLE', 'A Fanciful Yarn of a Crocodile And a Forensic Psychologist who must Discover a Crocodile in The Outback', 2006, 1, None, 3, Decimal('2.99'), 65, Decimal('18.99'), 'PG', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (537, 'LOVER TRUMAN', 'A Emotional Yarn of a Robot And a Boy who must Outgun a Technical Writer in A U-Boat', 2006, 1, None, 3, Decimal('2.99'), 75, Decimal('29.99'), 'G', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (541, 'LUKE MUMMY', 'A Taut Character Study of a Boy And a Robot who must Redeem a Mad Scientist in Ancient India', 2006, 1, None, 5, Decimal('2.99'), 74, Decimal('21.99'), 'NC-17', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (542, 'LUST LOCK', 'A Fanciful Panorama of a Hunter And a Dentist who must Meet a Secret Agent in The Sahara Desert', 2006, 1, None, 3, Decimal('2.99'), 52, Decimal('28.99'), 'G', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (548, 'MAGNIFICENT CHITTY', 'A Insightful Story of a Teacher And a Hunter who must Face a Mad Cow in California', 2006, 1, None, 3, Decimal('2.99'), 53, Decimal('27.99'), 'R', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (550, 'MAGUIRE APACHE', 'A Fast-Paced Reflection of a Waitress And a Hunter who must Defeat a Forensic Psychologist in A Baloon', 2006, 1, None, 6, Decimal('2.99'), 74, Decimal('22.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (558, 'MANNEQUIN WORST', 'A Astounding Saga of a Mad Cow And a Pastry Chef who must Discover a Husband in Ancient India', 2006, 1, None, 3, Decimal('2.99'), 71, Decimal('18.99'), 'PG-13', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
# ...
#  (799, 'SIMON NORTH', 'A Thrilling Documentary of a Technical Writer And a A Shark who must Face a Pioneer in A Shark Tank', 2006, 1, None, 3, Decimal('0.99'), 51, Decimal('26.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (805, 'SLEEPLESS MONSOON', 'A Amazing Saga of a Moose And a Pastry Chef who must Escape a Butler in Australia', 2006, 1, None, 5, Decimal('4.99'), 64, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (807, 'SLEUTH ORIENT', 'A Fateful Character Study of a Husband And a Dog who must Find a Feminist in Ancient India', 2006, 1, None, 4, Decimal('0.99'), 87, Decimal('25.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (808, 'SLING LUKE', 'A Intrepid Character Study of a Robot And a Monkey who must Reach a Secret Agent in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('0.99'), 84, Decimal('10.99'), 'R', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (811, 'SMILE EARRING', 'A Intrepid Drama of a Teacher And a Butler who must Build a Pastry Chef in Berlin', 2006, 1, None, 4, Decimal('2.99'), 60, Decimal('29.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (812, 'SMOKING BARBARELLA', 'A Lacklusture Saga of a Mad Cow And a Mad Scientist who must Sink a Cat in A MySQL Convention', 2006, 1, None, 7, Decimal('0.99'), 50, Decimal('13.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (815, 'SNATCHERS MONTEZUMA', 'A Boring Epistle of a Sumo Wrestler And a Woman who must Escape a Man in The Canadian Rockies', 2006, 1, None, 4, Decimal('2.99'), 74, Decimal('14.99'), 'PG-13', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (816, 'SNOWMAN ROLLERCOASTER', 'A Fateful Display of a Lumberjack And a Girl who must Succumb a Mad Cow in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('0.99'), 62, Decimal('27.99'), 'G', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (824, 'SPARTACUS CHEAPER', 'A Thrilling Panorama of a Pastry Chef And a Secret Agent who must Overcome a Student in A Manhattan Penthouse', 2006, 1, None, 4, Decimal('4.99'), 52, Decimal('19.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (828, 'SPIKING ELEMENT', 'A Lacklusture Epistle of a Dentist And a Technical Writer who must Find a Dog in A Monastery', 2006, 1, None, 7, Decimal('2.99'), 79, Decimal('12.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (837, 'STAGE WORLD', 'A Lacklusture Panorama of a Woman And a Frisbee who must Chase a Crocodile in A Jet Boat', 2006, 1, None, 4, Decimal('2.99'), 85, Decimal('19.99'), 'PG', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (840, 'STAMPEDE DISTURBING', 'A Unbelieveable Tale of a Woman And a Lumberjack who must Fight a Frisbee in A U-Boat', 2006, 1, None, 5, Decimal('0.99'), 75, Decimal('26.99'), 'R', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (845, 'STEPMOM DREAM', 'A Touching Epistle of a Crocodile And a Teacher who must Build a Forensic Psychologist in A MySQL Convention', 2006, 1, None, 7, Decimal('4.99'), 48, Decimal('9.99'), 'NC-17', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (849, 'STORM HAPPINESS', 'A Insightful Drama of a Feminist And a A Shark who must Vanquish a Boat in A Shark Tank', 2006, 1, None, 6, Decimal('0.99'), 57, Decimal('28.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (856, 'STREETCAR INTENTIONS', 'A Insightful Character Study of a Waitress And a Crocodile who must Sink a Waitress in The Gulf of Mexico', 2006, 1, None, 5, Decimal('4.99'), 73, Decimal('11.99'), 'R', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (862, 'SUMMER SCARFACE', 'A Emotional Panorama of a Lumberjack And a Hunter who must Meet a Girl in A Shark Tank', 2006, 1, None, 5, Decimal('0.99'), 53, Decimal('25.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (866, 'SUNSET RACER', 'A Awe-Inspiring Reflection of a Astronaut And a A Shark who must Defeat a Forensic Psychologist in California', 2006, 1, None, 6, Decimal('0.99'), 48, Decimal('28.99'), 'NC-17', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (867, 'SUPER WYOMING', 'A Action-Packed Saga of a Pastry Chef And a Explorer who must Discover a A Shark in The Outback', 2006, 1, None, 5, Decimal('4.99'), 58, Decimal('10.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (869, 'SUSPECTS QUILLS', 'A Emotional Epistle of a Pioneer And a Crocodile who must Battle a Man in A Manhattan Penthouse', 2006, 1, None, 4, Decimal('2.99'), 47, Decimal('22.99'), 'PG', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (877, 'TAXI KICK', 'A Amazing Epistle of a Girl And a Woman who must Outrace a Waitress in Soviet Georgia', 2006, 1, None, 4, Decimal('0.99'), 64, Decimal('23.99'), 'PG-13', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (878, 'TEEN APOLLO', 'A Awe-Inspiring Drama of a Dog And a Man who must Escape a Robot in A Shark Tank', 2006, 1, None, 3, Decimal('4.99'), 74, Decimal('25.99'), 'G', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (881, 'TEMPLE ATTRACTION', 'A Action-Packed Saga of a Forensic Psychologist And a Woman who must Battle a Womanizer in Soviet Georgia', 2006, 1, None, 5, Decimal('4.99'), 71, Decimal('13.99'), 'PG', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (883, 'TEQUILA PAST', 'A Action-Packed Panorama of a Mad Scientist And a Robot who must Challenge a Student in Nigeria', 2006, 1, None, 6, Decimal('4.99'), 53, Decimal('17.99'), 'PG', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (884, 'TERMINATOR CLUB', 'A Touching Story of a Crocodile And a Girl who must Sink a Man in The Gulf of Mexico', 2006, 1, None, 5, Decimal('4.99'), 88, Decimal('11.99'), 'R', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (888, 'THIN SAGEBRUSH', 'A Emotional Drama of a Husband And a Lumberjack who must Build a Cat in Ancient India', 2006, 1, None, 5, Decimal('4.99'), 53, Decimal('9.99'), 'PG-13', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (891, 'TIMBERLAND SKY', 'A Boring Display of a Man And a Dog who must Redeem a Girl in A U-Boat', 2006, 1, None, 3, Decimal('0.99'), 69, Decimal('13.99'), 'G', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (894, 'TOMATOES HELLFIGHTERS', 'A Thoughtful Epistle of a Madman And a Astronaut who must Overcome a Monkey in A Shark Tank', 2006, 1, None, 6, Decimal('0.99'), 68, Decimal('23.99'), 'PG', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (904, 'TRAIN BUNCH', 'A Thrilling Character Study of a Robot And a Squirrel who must Face a Dog in Ancient India', 2006, 1, None, 3, Decimal('4.99'), 71, Decimal('26.99'), 'R', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (910, 'TREATMENT JEKYLL', 'A Boring Story of a Teacher And a Student who must Outgun a Cat in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('0.99'), 87, Decimal('19.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (911, 'TRIP NEWTON', 'A Fanciful Character Study of a Lumberjack And a Car who must Discover a Cat in An Abandoned Amusement Park', 2006, 1, None, 7, Decimal('4.99'), 64, Decimal('14.99'), 'PG-13', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (912, 'TROJAN TOMORROW', 'A Astounding Panorama of a Husband And a Sumo Wrestler who must Pursue a Boat in Ancient India', 2006, 1, None, 3, Decimal('2.99'), 52, Decimal('9.99'), 'PG', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (914, 'TROUBLE DATE', 'A Lacklusture Panorama of a Forensic Psychologist And a Woman who must Kill a Explorer in Ancient Japan', 2006, 1, None, 6, Decimal('2.99'), 61, Decimal('13.99'), 'PG', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (916, 'TURN STAR', 'A Stunning Tale of a Man And a Monkey who must Chase a Student in New Orleans', 2006, 1, None, 3, Decimal('2.99'), 80, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (919, 'TYCOON GATHERING', 'A Emotional Display of a Husband And a A Shark who must Succumb a Madman in A Manhattan Penthouse', 2006, 1, None, 3, Decimal('4.99'), 82, Decimal('17.99'), 'G', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (920, 'UNBREAKABLE KARATE', 'A Amazing Character Study of a Robot And a Student who must Chase a Robot in Australia', 2006, 1, None, 3, Decimal('0.99'), 62, Decimal('16.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (923, 'UNFAITHFUL KILL', 'A Taut Documentary of a Waitress And a Mad Scientist who must Battle a Technical Writer in New Orleans', 2006, 1, None, 7, Decimal('2.99'), 78, Decimal('12.99'), 'R', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (928, 'UPTOWN YOUNG', 'A Fateful Documentary of a Dog And a Hunter who must Pursue a Teacher in An Abandoned Amusement Park', 2006, 1, None, 5, Decimal('2.99'), 84, Decimal('16.99'), 'PG', 'Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (931, 'VALENTINE VANISHING', 'A Thrilling Display of a Husband And a Butler who must Reach a Pastry Chef in California', 2006, 1, None, 7, Decimal('0.99'), 48, Decimal('9.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (932, 'VALLEY PACKER', 'A Astounding Documentary of a Astronaut And a Boy who must Outrace a Sumo Wrestler in Berlin', 2006, 1, None, 3, Decimal('0.99'), 73, Decimal('21.99'), 'G', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (937, 'VARSITY TRIP', 'A Action-Packed Character Study of a Astronaut And a Explorer who must Reach a Monkey in A MySQL Convention', 2006, 1, None, 7, Decimal('2.99'), 85, Decimal('14.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (940, 'VICTORY ACADEMY', 'A Insightful Epistle of a Mad Scientist And a Explorer who must Challenge a Cat in The Sahara Desert', 2006, 1, None, 6, Decimal('0.99'), 64, Decimal('19.99'), 'PG-13', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (943, 'VILLAIN DESPERATE', 'A Boring Yarn of a Pioneer And a Feminist who must Redeem a Cat in An Abandoned Amusement Park', 2006, 1, None, 4, Decimal('4.99'), 76, Decimal('27.99'), 'PG-13', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (947, 'VISION TORQUE', 'A Thoughtful Documentary of a Dog And a Man who must Sink a Man in A Shark Tank', 2006, 1, None, 5, Decimal('0.99'), 59, Decimal('16.99'), 'PG-13', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (951, 'VOYAGE LEGALLY', 'A Epic Tale of a Squirrel And a Hunter who must Conquer a Boy in An Abandoned Mine Shaft', 2006, 1, None, 6, Decimal('0.99'), 78, Decimal('28.99'), 'PG-13', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (954, 'WAKE JAWS', 'A Beautiful Saga of a Feminist And a Composer who must Challenge a Moose in Berlin', 2006, 1, None, 7, Decimal('4.99'), 73, Decimal('18.99'), 'G', 'Trailers,Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (957, 'WAR NOTTING', 'A Boring Drama of a Teacher And a Sumo Wrestler who must Challenge a Secret Agent in The Canadian Rockies', 2006, 1, None, 7, Decimal('4.99'), 80, Decimal('26.99'), 'G', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (959, 'WARLOCK WEREWOLF', 'A Astounding Yarn of a Pioneer And a Crocodile who must Defeat a A Shark in The Outback', 2006, 1, None, 6, Decimal('2.99'), 83, Decimal('10.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (962, 'WASTELAND DIVINE', 'A Fanciful Story of a Database Administrator And a Womanizer who must Fight a Database Administrator in Ancient China', 2006, 1, None, 7, Decimal('2.99'), 85, Decimal('18.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (963, 'WATCH TRACY', 'A Fast-Paced Yarn of a Dog And a Frisbee who must Conquer a Hunter in Nigeria', 2006, 1, None, 5, Decimal('0.99'), 78, Decimal('12.99'), 'PG', 'Trailers,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (964, 'WATERFRONT DELIVERANCE', 'A Unbelieveable Documentary of a Dentist And a Technical Writer who must Build a Womanizer in Nigeria', 2006, 1, None, 4, Decimal('4.99'), 61, Decimal('17.99'), 'G', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (966, 'WEDDING APOLLO', 'A Action-Packed Tale of a Student And a Waitress who must Conquer a Lumberjack in An Abandoned Mine Shaft', 2006, 1, None, 3, Decimal('0.99'), 70, Decimal('14.99'), 'PG', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (968, 'WEREWOLF LOLA', 'A Fanciful Story of a Man And a Sumo Wrestler who must Outrace a Student in A Monastery', 2006, 1, None, 6, Decimal('4.99'), 79, Decimal('19.99'), 'G', 'Trailers,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (970, 'WESTWARD SEABISCUIT', 'A Lacklusture Tale of a Butler And a Husband who must Face a Boy in Ancient China', 2006, 1, None, 7, Decimal('0.99'), 52, Decimal('11.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (972, 'WHISPERER GIANT', 'A Intrepid Story of a Dentist And a Hunter who must Confront a Monkey in Ancient Japan', 2006, 1, None, 4, Decimal('4.99'), 59, Decimal('24.99'), 'PG-13', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (977, 'WINDOW SIDE', 'A Astounding Character Study of a Womanizer And a Hunter who must Escape a Robot in A Monastery', 2006, 1, None, 3, Decimal('2.99'), 85, Decimal('25.99'), 'R', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (980, 'WIZARD COLDBLOODED', 'A Lacklusture Display of a Robot And a Girl who must Defeat a Sumo Wrestler in A MySQL Convention', 2006, 1, None, 4, Decimal('4.99'), 75, Decimal('12.99'), 'PG', 'Commentaries,Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (981, 'WOLVES DESIRE', 'A Fast-Paced Drama of a Squirrel And a Robot who must Succumb a Technical Writer in A Manhattan Penthouse', 2006, 1, None, 7, Decimal('0.99'), 55, Decimal('13.99'), 'NC-17', 'Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (986, 'WONKA SEA', 'A Brilliant Saga of a Boat And a Mad Scientist who must Meet a Moose in Ancient India', 2006, 1, None, 6, Decimal('2.99'), 85, Decimal('24.99'), 'NC-17', 'Trailers,Commentaries', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (989, 'WORKING MICROCOSMOS', 'A Stunning Epistle of a Dentist And a Dog who must Kill a Madman in Ancient China', 2006, 1, None, 4, Decimal('4.99'), 74, Decimal('22.99'), 'R', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (995, 'YENTL IDAHO', 'A Amazing Display of a Robot And a Astronaut who must Fight a Womanizer in Berlin', 2006, 1, None, 5, Decimal('4.99'), 86, Decimal('11.99'), 'R', 'Trailers,Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (1000, 'ZORRO ARK', 'A Intrepid Panorama of a Mad Scientist And a Boy who must Redeem a Boy in A Monastery', 2006, 1, None, 3, Decimal('4.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))]

# %%
# %%sql
# show databases;

# %%
# %sql use northwind;

# %%
# %sql show tables;

# %%
# %sql select * from customers limit 20;

# %% [markdown]
# ### ASCII()
#
# - ASCII（）函数返回特定字符的ASCII值
# - 如果输入了多个字符，它将只返回第一个字符的值

# %%
# %sql select CompanyName,ascii(CompanyName) from customers limit 10;

# %% [markdown]
# ### char_length() & CHARACTER_LENGTH()
#
# - 返回字符串的长度;
# - 两个函数等价

# %%
# %sql SELECT ContactName,CHAR_LENGTH(ContactName) AS LengthOfName FROM Customers limit 20;

# %% [markdown]
# ### concat()
#
# - CONCAT(expression1, expression2, expression3,...)
# - 用于拼接字符串
# - 如果任何表达式为NULL值，则返回NULL

# %%
# %sql SELECT Country,city,CONCAT(Country,'+', city) AS Address FROM Customers limit 20;
# %sql SELECT CONCAT(Country,"", city) AS Address FROM Customers limit 20;

# %% [markdown]
# ### concat_ws()
#
# - CONCAT_WS(separator, expression1, expression2, expression3,...)
# - 将多个表达式相加，并在它们之间添加一个“-”分隔符
# - 其中separator是必需的，即在每个表达式之间添加的分隔符。如果分隔符为NULL，则此函数返回NULL。
# - 该函数将跳过具有NULL值的表达式

# %%
# %sql SELECT Country, city,CONCAT_ws('+',Country, city) AS Address FROM Customers limit 10;

# %% [markdown]
# ### field()
#
# - FIELD(value, val1, val2, val3, ...) 返回字符串列表中“q”的索引位置
# - 函数返回值列表中某个值的索引位置
# - 此函数执行不区分大小写的搜索。
# - 注意：如果在值列表中找不到指定的值，此函数将返回0。如果值为NULL，此函数将返回0。

# %%
# %sql SELECT FIELD('q', 's', 'q', 'l');
# %sql SELECT City,Region,address,FIELD('Lule',City,Region,address),FIELD('Berlin',City,Region,address) from customers limit 10;

# %% [markdown]
# ### find_in_set()
#
# - FIND_IN_SET(string, string_list) 在字符串列表string_list中搜索string：
# - 函数的作用是返回字符串列表中字符串的位置。
# - 如果在string_list中找不到字符串，则此函数返回0
# - 如果字符串或字符串列表为NULL，则此函数返回NULL
# - 如果string_list是空字符串（“”），则此函数返回0

# %%
# %%sql
# # SELECT FIND_IN_SET('q', null);
# SELECT FIND_IN_SET('q', 'S,q ');
# select City,find_in_set('bu',City) from customers limit 15;

# %% [markdown]
# ### format()
#
# - FORMAT(number, decimal_places)
# - FORMAT（）函数将数字格式化为类似“#，####，###.##”的格式，四舍五入到指定的小数位数，然后将结果作为字符串返回。
# - number:要格式化的数字；decimal_places：数字的小数位数。如果此参数为0，则此函数返回一个没有小数位数的字符串

# %%
# %%sql
# select UnitPrice,format(UnitPrice,2) as re from products limit 10;

# %% [markdown]
# ### insert()
#
# - INSERT(string, position, number, string2)
# - 该函数在指定位置的字符串中插入一定数量的字符
# - string是将要修改的字符串；position是插入字符串的位置；number是要替换的字符数；string2是要插入字符串的字符串
# - 如果位置在字符串长度之外，此函数将返回字符串
# - 如果数字大于字符串其余部分的长度，则此函数将替换从位置到字符串末尾的字符串

# %%
# %%sql
# select ProductName,insert(ProductName,2,2,'yy') as re
# from products;

# %% [markdown]
# ### instr()
#
# - INSTR(string1, string2)
# - string1是将要搜索的字符串；string2是要在字符串1中搜索的字符串，如果找不到string2，返回0
# - 该函数返回一个字符串在另一个字符串中第一次出现的位置
# - 此函数执行不区分大小写的搜索。

# %%
# %%sql
# select ProductName,instr(ProductName,'e') as low,instr(ProductName,'E') as upper
# from products limit 20;

# %% [markdown]
# ### lcase()
#
# - LCASE(text)
# - 该函数的作用是将字符串转换为小写。
# - LOWER（）函数效果与LCASE（）相同

# %%
# %%sql
# select ProductName,lcase(ProductName) as low
# from products limit 20;

# %% [markdown]
# ### left()
#
# - LEFT(string, number_of_chars)
# - string是要从中提取的字符串；number_of_chars是要提取的字符数。如果此参数大于字符串中的字符数，则此函数将返回字符串
# - LEFT（）函数从字符串中提取多个字符（从左起）
# - 从右提取是RIGHT（）函数。

# %%
# %%sql
# select ProductName,left(ProductName,3),left(ProductName,20) as le
# from products limit 20;

# %% [markdown]
# ### length()
#
# - LENGTH(string)
# - LENGTH（）函数返回字符串的长度（以字节为单位）

# %%
# %sql SELECT ContactName,LENGTH(ContactName) from Customers limit 20;

# %% [markdown]
# ### locate()
#
# - locate(substring,string,start)
# - locate函数用于判断字符串substring在字符串string中的位置，start为查找的起始位置，默认值为1

# %%
# %sql SELECT LOCATE('i','string');

# %% [markdown]
# ### lower()
#
# - lower(string)
# - lower将字符串string转换为小写

# %%
# %sql SELECT LOWER(customerid) FROM customers;

# %% [markdown]
# ### lpad()
#
# - lpad(string,length,lpad_string)
# - lpad函数用于在左边填充字符串。string为要填充的字符串，length为填充完之后的字符串长度，lpad-string为用于填充的字符串

# %%
# %sql SELECT LPAD('PLE',5,'AP');

# %% [markdown]
# ### ltrim()
#
# - ltrim(string)
# - lrtim函数用于移除字符串string左侧的空格

# %%
# %sql SELECT LTRIM("   STD");

# %% [markdown]
# ### mid()
#
# - mid(string,start,length)
# - mid函数用于返回字符串string中的子字符串，start为起始位置，length为子字符串的长度

# %%
# %sql SELECT MID(customerid,1,5) FROM customers;

# %% [markdown]
# ### position()
#
# - position(substring IN string)
# - position函数用于返回字符串substring第一次在字符串string中出现的位置

# %%
# %sql SELECT POSITION('A' IN customerid) FROM customers;

# %% [markdown]
# ### repeat()
#
# - repeat(string,number)
# - repeat函数用于将字符串string重复number次

# %%
# %sql SELECT REPEAT(customerid,2) FROM customers;

# %% [markdown]
# ### replace()
#
# - replace(string,old_string,new_string)
# - replace函数用于将字符串string中的子字符串old_string替换成new_string

# %%
# %sql SELECT REPLACE(customerid,'A','B') FROM customers;

# %% [markdown]
# ### reverse()
#
# - reverse(string)
# - reverse函数用于反转字符串string

# %%
# %sql SELECT REVERSE(customerid) FROM customers;

# %% [markdown]
# ### right()
#
# - right(string,number)
# - right函数用于从右边截取字符串string中的子字符串，子字符串的长度为number

# %%
# %sql SELECT RIGHT(customerid,3) FROM customers;

# %% [markdown]
# ### rpad()
#
# - rpad(string,length,rpad_string)
# - rpad函数将rpad_string字符串用于填充字符串string，填充完后的字符串长度为length

# %%
# %sql SELECT RPAD('APP',2,'LE');

# %% [markdown]
# ### rtrim()
#
# - rtrim(string)
# - rtrim函数用于消除字符串string右边的空白

# %%
# %sql SELECT RTRIM('CUSTOMER   ');

# %% [markdown]
# ### space()
#
# - space(number)
# - space用于返回number长度的空格

# %%
# %sql SELECT SPACE(10);

# %% [markdown]
# ### STRCMP()
#
#  - STRCMP(string1,string2)
#  - STRCMP用于比较两个字符串的大小。若一样大，则返回0；若string1大，则返回1；否则返回-1

# %%
# %sql SELECT STRCMP(first_name,last_name) FROM actor LIMIT 5;

# %% [markdown]
# ### SUBSTR()
#  - SUBSTR(string,start,length) 或 SUBSTR(string FROM start FOR length)
#  - SUBSTR()函数用于从字符串中提取子字符串（从任意位置开始）
#  - 其中start为起始位置，可正可负，如果是正数，此函数将从字符串的开头提取；如果是负数，此函数将从字符串的末尾提取
#  - 其中length为子字符串长度，若省略，将返回整个字符串（从起始位置）

# %%
# %sql SELECT SUBSTR(city,1,3) FROM city LIMIT 5;

# %% [markdown]
# ### SUBSTRING()
#  - SUBSTRING(string,start,length) 或 SUBSTRING(string FROM start FOR length)
#  - SUBSTRING()用法等同于SUBSTR()和MID()

# %%
# %sql SELECT SUBSTRING(country FROM 2 FOR 2) FROM country LIMIT 5;

# %% [markdown]
# ### SUBSTRING_INDEX()
#  - SUBSTRING_INDEX(string,delimiter,number)
#  - SUBSTRING_INDEX()函数在指定数量的分隔符出现之前返回字符串的子字符串
#  - 其中，number是搜索分隔符的次数，可正可负。如果是正数，则此函数将返回分隔符左侧的所有值；如果是负数，则此函数将返回分隔符右侧的所有值

# %%
# %sql select SUBSTRING_INDEX(email,'.',2) FROM customer LIMIT 5;

# %% [markdown]
# ### TRIM()
#
#  - TRIM(string)
#  - TRIM()函数从字符串中删除前后空格

# %%
# %sql SELECT TRIM(first_name) FROM actor LIMIT 5;

# %% [markdown]
# ### UCASE()
#
#  - UCASE(text)
#  - UCASE()函数用于将字符串转换为大写

# %%
# %sql SELECT UCASE(city) FROM city LIMIT 5;

# %% [markdown]
# ### UPPER()
#
#  - UPPER(text)
#  - UPPER()函数用于将字符串转换为大写

# %%
# %sql SELECT UPPER(country) FROM country LIMIT 5;

# %% [markdown]
# ### ABS()
#
#  - ABS(number)
#  - ABS()函数用于返回一个数的绝对值

# %%
# %sql SELECT ABS(actor_id) FROM actor LIMIT 5;

# %% [markdown]
# ### ACOS()
#
#  - ACOS(number)
#  - ACOS()函数用于返回一个数的反余弦，若number不在[-1,1]这个区间，则返回NULL

# %%
# %sql SELECT ACOS(film_id) FROM film LIMIT 5;

# %% [markdown]
# ### ASIN()
#
#  - ASIN(number)
#  - ASIN()函数用于返回一个数的反正弦，若number不在[-1,1]这个区间，则返回NULL

# %%
# %sql SELECT ASIN(film_id) FROM film LIMIT 5;

# %% [markdown]
# ### ATAN()
#
#  - ATAN(number) 或 ATAN(a,b)
#  - ATAN()函数用于返回一个或两个数的反正切

# %%
# %sql SELECT ATAN(film_id,language_id) FROM film LIMIT 5;

# %% [markdown]
# ### ATAN2()
#
#  - ATAN2(a,b)
#  - ATAN2()函数用于返回两个数的反正切

# %%
# %sql SELECT ATAN(film_id,language_id) FROM film LIMIT 5;

# %% [markdown]
# ### AVG()
#
#  - AVG(expression)
#  - AVG()函数用于返回表达式的平均值
#  - 其中expression可以是字段或公式

# %%
# %sql SELECT AVG(rental_id) FROM rental;

# %% [markdown]
# ### CEIL()
# - CEIL(number)
# - 参数值number是必填项，数值类型
# - CEIL()函数返回大于或等于number的最小整数值
# - 等于CEILING()函数

# %%
# %sql SELECT CEIL(max(amount)) from payment;

# %% [markdown]
# ### CEILING()
# - CEILING(number)
# - 参数值number是必填项，为数值类型
# - CEILING()函数返回大于或等于number的最小整数值
# - 此函数等于CEIL()函数

# %%
# %sql SELECT CEILING(max(length)) from film;

# %% [markdown]
# ### COS()
# - COS(number)
# - 参数值number是必填项，为数值类型
# - COS()函数返回number的余弦值

# %%
# %sql SELECT COS(rental_duration) from film LIMIT 10;

# %% [markdown]
# ### COT()
# - COT(number)
# - 参数number是必填项，为数值类型；如果数字为0，则返回错误或NULL
# - COT()函数返回number的余切值

# %%
# %sql SELECT COT(rental_duration) from film LIMIT 10;

# %% [markdown]
# ### COUNT()
# - COUNT(expression)
# - 参数expression是必填项，为字段或字符串类型
# - COUNT()函数返回参数expression的数量，不计算空值

# %%
# %sql SELECT COUNT(store_id) from inventory where store_id=1;

# %% [markdown]
# ### DEGREES()
# - DEGREES(number)
# - 参数值number是必填项，为数值类型
# - DEGREES()函数将弧度值转换为度值：2pi弧度=360度
# - RADIANS()将度值转换为弧度值
# - PI()返回圆周率的值

# %%
# %sql SELECT DEGREES(amount) from payment LIMIT 10;

# %% [markdown]
# ### DIV
# - x DIV y
# - x，y都是必填项；x是被除数，y是除数
# - DIV 函数用于整数除，返回整数

# %%
# %sql SELECT SUM(amount) DIV COUNT(*) from payment GROUP BY staff_id;

# %% [markdown]
# ### EXP()
# - EXP(number)
# - 参数number为必填项
# - EXP()函数返回自然常数e的number次幂
# - LOG()函数返回指定数字的自然对数
# - LN()函数返回数字的自然对数

# %%
# %sql SELECT EXP(category_id) from film_category ORDER BY film_id LIMIT 10;

# %% [markdown]
# ### FLOOR()
# - FLOOR(number)
# - 参数值number是必填项，为数值类型
# - FLOOR()函数返回小于或等于参数值numberd的最大整数值
# - CEIL()函数、CEILING()函数返回大于或等于number的最小整数值

# %%
# %sql SELECT FLOOR(rental_rate) from film LIMIT 10;

# %% [markdown]
# ### GREATEST()
# - GREATEST(arg1, arg2, arg3, ...)
# - arg1, arg2, arg3, ...是必填项，是要计算的参数列表
# - GREATEST()函数返回参数列表的最大值
# - LEAST（）函数返回参数列表的最小值
# - MINIMUM（）函数返回参数列表的最小值

# %%
# %sql SELECT GREATEST((SELECT MAX(rental_rate) from film),(SELECT MAX(replacement_cost) from film));

# %% [markdown]
# ### LEAST()
# - LEAST(arg1, arg2, arg3, ...)
# - arg1, arg2, arg3, ...是必填项，是要计算的参数列表
# - LEAST（）函数返回参数列表的最小值
# - MINIMUM（）函数返回参数列表的最小值
# - GREATEST()函数返回参数列表的最大值

# %%
# %sql SELECT LEAST((SELECT MIN(rental_rate) from film),(SELECT MIN(replacement_cost) from film));

# %% [markdown]
# ### LN()
# - LN(number)
# - 参数number为必填项,为大于0的数字
# - LN（）函数返回数字number的自然对数
# - LOG()函数返回指定数字的自然对数
# - EXP()函数返回自然常数e的number次幂

# %%
# %sql SELECT LN(country_id) from city ORDER BY city_id LIMIT 10;

# %% [markdown]
# ### LOG()
# - LOG(number) 或 LOG(base, number)
# - 参数number为必填项，为大于0的数字；base必须大于1
# - LOG()函数返回指定数字的自然对数
# - LN（）函数返回数字number的自然对数
# - EXP()函数返回自然常数e的number次幂

# %%
# %sql SELECT LOG(country_id) from city ORDER BY city_id LIMIT 10;

# %% [markdown]
# ### LOG10()
# - LOG10(number)
# - 参数number为大于0的数字
# - LOG10（）函数将参数number的自然对数返回到以10为基数的对数
# - LOG()函数返回指定数字的自然对数

# %%
# %sql SELECT LOG10(country_id) from city ORDER BY city_id LIMIT 10;

# %% [markdown]
# ### SUM()
# - SUM(expression)
# - SUM()函数计算一组值的总和。
# - 参数值expression是必填项字段或公式
# - 注意：空值将被忽略。

# %%
# %%sql
# SELECT SUM(LENGTH) FROM FILM;

# %% [markdown]
# ### TAN()
# - TAN(number)
# - 参数值number是必填项，为数值类型
# - TAN()函数返回数字的正切值。

# %%
# %%sql
# SELECT TAN(rental_duration) FROM FILM limit 10;

# %% [markdown]
# ### TRUNCATE()
# - TRUNCATE(number, decimals)
# - TRUNCATE()函数将数字截断为指定的小数位数。
# - 注意：另请参阅FLOOR()、CEIL()、CEILING()和ROUND()函数。
# - 参数值number必填，为要截断的数字；
# 参数值decimals必填，为要截断的小数位数。

# %%
# %%sql
# SELECT TRUNCATE(amount,1) FROM payment limit 10;

# %% [markdown]
# ### CURRENT_DATE()
# - CURRENT_DATE()函数返回当前日期。
# - 注意：日期返回为 “YYYY-MM-DD”（字符串）或 YYYYMMDD（数字）。
# - 注意：此函数等于CURDATE()函数。

# %%
# %sql SELECT CURRENT_DATE();

# %%
# %sql SELECT CURRENT_DATE() + 1;

# %% [markdown]
# ### CURRENT_TIME()
# - CURRENT_TIME()
# - CURRENT_TIME()函数返回当前时间。
# - 注意：返回时间为 “HH-MM-SS”（字符串）或 HHMMSS.uuuuu（数字）。
# - 注意：此函数等于 CURTIME()函数。

# %%
# %%sql
# SELECT CURRENT_TIME();

# %%
# %%sql
# SELECT CURRENT_TIME()+1;

# %% [markdown]
# ### CURRENT_TIMESTAMP()
# - CURRENT_TIMESTAMP()
# - CURRENT_TIMESTAMP()函数返回当前日期和时间。
# - 注意：日期和时间返回为“YYYY-MM-DD HH-MM-SS” （字符串）或YYYYMMDDHHMMSS.uuuuuuuu(numeric)。

# %%
# %sql SELECT CURRENT_TIMESTAMP();

# %%
# %sql SELECT CURRENT_TIMESTAMP()+1;

# %% [markdown]
# ### CASE
# - CASE
#     WHEN condition1 THEN result1
#     WHEN condition2 THEN result2
#     WHEN conditionN THEN resultN
#     ELSE result
#   END;
# -CASE 语句遍历条件，并在满足第一个条件时返回一个值（如 IF-THEN-ELSE 语句）。因此，一旦条件为真，它将停止读取并返回结果。如果没有条件为真，它将返回ELSE 子句中的值。如果没有ELSE部分并且没有条件为真，则返回 NULL。
# - 参数condition1, condition2, ...conditionN必填。为条件。评估的顺序与列出的顺序相同。
# - 参数result1, result2, ...resultN必填。条件为true时返回值。

# %%
# %%sql
# SELECT film_id,length,
# (CASE
#     WHEN length > 100 THEN "FIRST"
#     WHEN length = 50 THEN "SECOND"
#     ELSE "THIRD"
# END) AS LEVEL
# FROM film
# limit 20;

# %% [markdown]
# - 按等级对FILM进行排序。但是，如果等级为 NULL，则按时长排序：

# %%
# %%sql
# SELECT * FROM film ORDER BY (CASE
#     WHEN rating IS NULL THEN length
#     ELSE rating
# END)
# limit 10;

# %% [markdown]
# ### CURRENT_USER()
# - CURRENT_USER()
# - 函数CURRENT_USER()返回服务器用来验证当前客户端的MySQL帐户的用户名和主机名。
# - 结果以UTF8字符的字符串形式返回设置。
# - 提示：另请参阅USER()函数。

# %%
# %sql SELECT CURRENT_USER();

# %% [markdown]
# ### DATABASE()
# - DATABASE()
# - DATABASE()函数返回当前数据库的名称。
# - 如果没有当前数据库，此函数返回NULL或""。

# %%
# %sql SELECT DATABASE();

# %% [markdown]
# ### IF()
# - IF(condition, value_if_true, value_if_false)
# - IF()函数在条件为TRUE时返回一个值，在条件为FALSE时返回另一个值。
# - 参数condition必填，为要测试的值；参数value_if_true必填，条件为TRUE时返回的值；参数value_if_false必填，条件为FALSE时返回的值

# %%
# %%sql
# SELECT payment_id,amount, IF(amount>5, "MORE", "LESS")
# FROM payment limit 10;

# %% [markdown]
# ### IFNULL()
# - IFNULL(expression, alt_value)
# - 如果表达式为NULL，则 IFNULL()函数返回指定的值。如果表达式不为 NULL，则此函数返回expression。
# - 参数expression必填，测试表达式是否为NULL；参数alt_value必填，表达式为NULL时返回的值

# %%
# %%sql
# SELECT film_id,IFNULL(original_language_id, '1')
# FROM film limit 10;

# %% [markdown]
# ### ISNULL()
# - ISNULL(expression)
# - ISNULL()函数返回 1 或 0，具体取决于表达式是否为 NULL。
# - 如果表达式为 NULL，则此函数返回 1。否则，它将返回 0。

# %%
# %%sql
# SELECT film_id,ISNULL(original_language_id)
# FROM film limit 10;

# %% [markdown]
# ### NULLIF()
# - NULLIF(expr1, expr2)
# - NULLIF()函数比较两个表达式，如果它们相等，则返回NULL。否则，将返回第一个表达式。

# %%
# %%sql
# SELECT NULLIF(return_date,last_update)
# FROM rental limit 10;
